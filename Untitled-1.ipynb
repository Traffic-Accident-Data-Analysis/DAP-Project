# %%
import pandas as pd
import os

# --- 1. CẤU HÌNH ĐƯỜNG DẪN ---
file_path = os.path.join('data', 'US_Accidents_March23.csv')

# --- 2. DANH SÁCH CỘT CẦN GIỮ LẠI ---
cols_to_keep = [
    # Mục tiêu & Thời gian
    'Severity', 'Start_Time', 'End_Time', #Mức độ nghiêm trọng, Thời gian bắt đầu, Thời gian kết thúc,
    
    # Vị trí
    'Start_Lat', 'Start_Lng', 'Distance(mi)', 'City','State' , # 'Vĩ độ_bắt đầu', 'Kinh độ_bắt đầu', 'Khoảng cách (dặm)', 'Thành phố',
    
    # Thời tiết
    'Temperature(F)', 
    'Humidity(%)', # độ ẩm 
    'Visibility(mi)', #tầm nhìn
    'Precipitation(in)', # lượng mưa 

    'Weather_Condition',#tình trạng thời tiết
    
    # Hạ tầng & Môi trường
    'Junction', 'Traffic_Signal', 'Sunrise_Sunset'
]

# --- 3. LOAD DỮ LIỆU ---
try:
    print(f" Đangload file từ: {file_path}")
    print(" Wait...")
    
    
  
    df = pd.read_csv(file_path, usecols=cols_to_keep)
    

    df['Precipitation(in)'] = df['Precipitation(in)'].fillna(0)

    print(f"Load thành công! Kích thước bảng: {df.shape}")
  
    
  
    display(df.sample(5))

except FileNotFoundError:
    print(" LỖI: Không tìm thấy file 'US_Accidents_March23.csv'!")
# Out:
#  Đangload file từ: data\US_Accidents_March23.csv
#  Wait...
# Load thành công! Kích thước bảng: (7728394, 16)
#          Severity                     Start_Time  \
# 5172831         2  2022-05-18 18:00:59.000000000
# 3827556         2            2022-06-21 04:49:22
# 200669          2            2017-01-17 20:26:36
# 4553125         2     2022-06-01 09:40:39.000000
# 3226241         3            2017-10-10 07:56:25
#
#                               End_Time  Start_Lat  Start_Lng  Distance(mi)  \
# 5172831  2022-05-18 20:03:37.000000000  40.727936 -74.101110         0.541
# 3827556            2022-06-21 06:30:47  38.988568 -76.890043         0.961
# 200669             2017-01-17 21:11:00  40.759762 -73.960991         0.010
# 4553125     2022-06-01 10:42:30.000000  40.741704 -73.783927         5.221
# 3226241            2017-10-10 08:55:37  45.069481 -93.286163         0.910
#
#                   City State  Temperature(F)  Humidity(%)  Visibility(mi)  \
# 5172831         Kearny    NJ            73.0         28.0            10.0
# 3827556         Lanham    MD             NaN          NaN            10.0
# 200669        New York    NY            39.0         96.0             2.5
# 4553125  Fresh Meadows    NY            61.0         75.0            10.0
# 3226241    Minneapolis    MN            30.9         85.0            10.0
#
#          Precipitation(in) Weather_Condition  Junction  Traffic_Signal  \
# 5172831               0.00     Mostly Cloudy     False           False
# 3827556               0.00              Fair     False           False
# 200669                0.01        Light Rain     False           False
# 4553125               0.00            Cloudy      True           False
# 3226241               0.00             Clear      True           False
#
#         Sunrise_Sunset
# 5172831            Day
# 3827556          Night
# 200669           Night
# 4553125            Day
# 3226241            Day

# %%
# --- BẮT ĐẦU XỬ LÝ DỮ LIỆU & FEATURE ENGINEERING (BẢN CHUẨN) ---
print("Đang xử lý dữ liệu thời gian...")

# 1. Chuyển đổi sang định dạng datetime (để máy tính cộng trừ được)
# errors='coerce': Nếu dòng nào lỗi ngày tháng thì biến thành NaT (Not a Time) chứ không báo lỗi dừng chương trình
df['Start_Time'] = pd.to_datetime(df['Start_Time'], errors='coerce')
df['End_Time'] = pd.to_datetime(df['End_Time'], errors='coerce')

# 2. TÁCH CỘT THỜI GIAN 
# Tách Giờ (0-23) -> Để biết sáng/chiều/tối
df['Hour'] = df['Start_Time'].dt.hour

# Tách Ngày (1-31)
df['Day'] = df['Start_Time'].dt.day

# Tách Tháng (1-12) -> QUAN TRỌNG: Để biết mùa (Đông/Hè)
df['Month'] = df['Start_Time'].dt.month

# Tách Năm (2016-2023)
df['Year'] = df['Start_Time'].dt.year

# --- [MỚI THÊM VÀO] Tách Thứ (Weekday) ---
# Giá trị trả về: 0 là Thứ 2, ..., 6 là Chủ Nhật
# Cột này bắt buộc phải có để vẽ biểu đồ Heatmap
df['Weekday'] = df['Start_Time'].dt.weekday

# 3. TẠO CỘT DURATION 
# Công thức: (Kết thúc - Bắt đầu) -> Đổi ra phút
df['Duration'] = (df['End_Time'] - df['Start_Time']).dt.total_seconds() / 60

# --- BƯỚC LỌC DỮ LIỆU NHIỄU ---

# 1. Lọc Duration: 
# Xóa các vụ có thời gian âm hoặc bằng 0 (vô lý)
df = df[df['Duration'] > 0]

# Kiểm tra số lượng vụ quá dài (> 24h)
print(f"Số vụ > 24h trước khi xử lý: {len(df[df['Duration'] > 1440])}")

# Capping: Quy hết các vụ > 1440 phút về 1440 phút
df.loc[df['Duration'] > 1440, 'Duration'] = 1440
print("Đã thực hiện Capping thành công!")
print(f"Giá trị Duration lớn nhất hiện tại: {df['Duration'].max()} phút")

# Xóa cột gốc để tiết kiệm RAM (Vì đã tách hết thông tin ra rồi)
df = df.drop(columns=['Start_Time', 'End_Time'])

# --- KIỂM TRA KẾT QUẢ ---
pd.set_option('display.max_columns', None)

print("--- 5 DÒNG ĐẦU TIÊN CỦA DỮ LIỆU SAU KHI XỬ LÝ ---")
display(df.head(25))

# In thêm kích thước bảng để xem còn bao nhiêu dòng sau khi lọc
print(f"\nKích thước dữ liệu hiện tại: {df.shape}")

print("\nThống kê cột Tháng (Month) xem có đủ từ 1 đến 12 không:")
print(df['Month'].value_counts().sort_index())

print("\nThống kê cột Thứ (Weekday) - 0:Thứ 2 -> 6:CN:")
print(df['Weekday'].value_counts().sort_index())
# Out:
# Đang xử lý dữ liệu thời gian...
# Số vụ > 24h trước khi xử lý: 28847
# Đã thực hiện Capping thành công!
# Giá trị Duration lớn nhất hiện tại: 1440.0 phút
# --- 5 DÒNG ĐẦU TIÊN CỦA DỮ LIỆU SAU KHI XỬ LÝ ---
#     Severity  Start_Lat  Start_Lng  Distance(mi)          City State  \
# 0          3  39.865147 -84.058723          0.01        Dayton    OH
# 1          2  39.928059 -82.831184          0.01  Reynoldsburg    OH
# 2          2  39.063148 -84.032608          0.01  Williamsburg    OH
# 3          3  39.747753 -84.205582          0.01        Dayton    OH
# 4          2  39.627781 -84.188354          0.01        Dayton    OH
# 5          3  40.100590 -82.925194          0.01   Westerville    OH
# 6          2  39.758274 -84.230507          0.00        Dayton    OH
# 7          3  39.770382 -84.194901          0.01        Dayton    OH
# 8          2  39.778061 -84.172005          0.00        Dayton    OH
# 9          3  40.100590 -82.925194          0.01   Westerville    OH
# 10         3  39.952812 -83.119293          0.01      Columbus    OH
# 11         3  39.932709 -82.830910          0.01  Reynoldsburg    OH
# 12         2  39.737633 -84.149933          0.00        Dayton    OH
# 13         2  39.790760 -84.241547          0.01        Dayton    OH
# 14         2  39.972038 -82.913521          0.01      Columbus    OH
# 15         2  39.745888 -84.170410          0.01        Dayton    OH
# 16         2  39.748329 -84.224007          0.01        Dayton    OH
# 17         2  39.752174 -84.239952          0.00        Dayton    OH
# 18         2  39.740669 -84.184135          0.01        Dayton    OH
# 19         2  39.790703 -84.244461          0.01        Dayton    OH
# 20         2  40.052509 -82.882332          0.00      Columbus    OH
# 21         2  39.773346 -84.224686          0.00        Dayton    OH
# 22         2  39.628288 -84.226151          0.01    Miamisburg    OH
# 23         3  40.023487 -82.994888          0.01      Columbus    OH
# 24         2  39.761379 -84.259216          0.01        Dayton    OH
#
#     Temperature(F)  Humidity(%)  Visibility(mi)  Precipitation(in)  \
# 0             36.9         91.0            10.0               0.02
# 1             37.9        100.0            10.0               0.00
# 2             36.0        100.0            10.0               0.00
# 3             35.1         96.0             9.0               0.00
# 4             36.0         89.0             6.0               0.00
# 5             37.9         97.0             7.0               0.03
# 6             34.0        100.0             7.0               0.00
# 7             34.0        100.0             7.0               0.00
# 8             33.3         99.0             5.0               0.00
# 9             37.4        100.0             3.0               0.02
# 10            35.6         93.0             5.0               0.00
# 11            37.4        100.0             3.0               0.02
# 12            33.8        100.0             3.0               0.00
# 13            36.0         89.0            10.0               0.00
# 14            37.4        100.0             3.0               0.02
# 15            33.8        100.0             3.0               0.00
# 16            35.6         99.0             7.0               0.00
# 17            36.0         89.0            10.0               0.00
# 18            37.4         93.0            10.0               0.00
# 19            36.0         89.0            10.0               0.00
# 20            33.8        100.0             2.0               0.01
# 21            36.0         89.0            10.0               0.00
# 22            35.1         89.0             6.0               0.02
# 23            37.0         96.0             8.0               0.00
# 24            37.9         76.0            10.0               0.00
#
#    Weather_Condition  Junction  Traffic_Signal Sunrise_Sunset  Hour  Day  \
# 0         Light Rain     False           False          Night   5.0  8.0
# 1         Light Rain     False           False          Night   6.0  8.0
# 2           Overcast     False            True          Night   6.0  8.0
# 3      Mostly Cloudy     False           False          Night   7.0  8.0
# 4      Mostly Cloudy     False            True            Day   7.0  8.0
# 5         Light Rain     False           False            Day   7.0  8.0
# 6           Overcast     False           False            Day   7.0  8.0
# 7           Overcast     False           False            Day   7.0  8.0
# 8      Mostly Cloudy     False           False            Day   8.0  8.0
# 9         Light Rain     False           False            Day   8.0  8.0
# 10              Rain      True           False            Day   8.0  8.0
# 11        Light Rain     False           False            Day   8.0  8.0
# 12          Overcast     False           False            Day   8.0  8.0
# 13     Mostly Cloudy     False            True            Day   8.0  8.0
# 14        Light Rain     False            True            Day   8.0  8.0
# 15          Overcast     False           False            Day   8.0  8.0
# 16     Mostly Cloudy     False           False            Day   8.0  8.0
# 17     Mostly Cloudy     False           False            Day   9.0  8.0
# 18          Overcast     False            True            Day   9.0  8.0
# 19     Mostly Cloudy     False           False            Day   9.0  8.0
# 20        Light Snow     False           False            Day  10.0  8.0
# 21     Mostly Cloudy     False           False            Day  10.0  8.0
# 22          Overcast     False            True            Day  11.0  8.0
# 23          Overcast     False           False            Day  12.0  8.0
# 24          Overcast     False            True            Day  12.0  8.0
#
#     Month    Year  Weekday  Duration
# 0     2.0  2016.0      0.0     314.0
# 1     2.0  2016.0      0.0      30.0
# 2     2.0  2016.0      0.0      30.0
# 3     2.0  2016.0      0.0      30.0
# 4     2.0  2016.0      0.0      30.0
# 5     2.0  2016.0      0.0      30.0
# 6     2.0  2016.0      0.0      30.0
# 7     2.0  2016.0      0.0      30.0
# 8     2.0  2016.0      0.0      30.0
# 9     2.0  2016.0      0.0      30.0
# 10    2.0  2016.0      0.0      30.0
# 11    2.0  2016.0      0.0      30.0
# 12    2.0  2016.0      0.0      30.0
# 13    2.0  2016.0      0.0      30.0
# 14    2.0  2016.0      0.0      30.0
# 15    2.0  2016.0      0.0      30.0
# 16    2.0  2016.0      0.0      30.0
# 17    2.0  2016.0      0.0      30.0
# 18    2.0  2016.0      0.0      30.0
# 19    2.0  2016.0      0.0      30.0
# 20    2.0  2016.0      0.0      30.0
# 21    2.0  2016.0      0.0      30.0
# 22    2.0  2016.0      0.0      30.0
# 23    2.0  2016.0      0.0      45.0
# 24    2.0  2016.0      0.0      45.0
# Kích thước dữ liệu hiện tại: (6985228, 20)
#
# Thống kê cột Tháng (Month) xem có đủ từ 1 đến 12 không:
# Month
# 1.0     652682
# 2.0     585606
# 3.0     501362
# 4.0     526210
# 5.0     505614
# 6.0     524750
# 7.0     463263
# 8.0     547206
# 9.0     593815
# 10.0    630325
# 11.0    695612
# 12.0    758783
# Name: count, dtype: int64
#
# Thống kê cột Thứ (Weekday) - 0:Thứ 2 -> 6:CN:
# Weekday
# 0.0    1108807
# 1.0    1177923
# 2.0    1195864
# 3.0    1196137
# 4.0    1237229
# 5.0     579153
# 6.0     490115
# Name: count, dtype: int64

# %%
# --- QUAN TRỌNG: TẠO BẢN SAO ---
df_dashboard = df.copy()
print(" Đang xử lý dữ liệu cho Dashboard...")

# 1. Capping Duration (Gán trần 24h = 1440 phút)
# Để biểu đồ không bị dẹt vì mấy vụ tai nạn ảo kéo dài cả năm
df_dashboard.loc[df_dashboard['Duration'] > 1440, 'Duration'] = 1440
df_dashboard = df_dashboard[df_dashboard['Duration'] > 0] # Bỏ lỗi âm

# 2. Điền giá trị thiếu 
# Cột số -> Điền Median
num_cols = ['Temperature(F)', 'Humidity(%)', 'Visibility(mi)', 'Distance(mi)']
for col in num_cols:
    if col in df_dashboard.columns:
        df_dashboard[col] = df_dashboard[col].fillna(df_dashboard[col].median())

# Cột chữ -> Điền Unknown/Mode
if 'City' in df_dashboard.columns:
    df_dashboard['City'] = df_dashboard['City'].fillna('Unknown')

if 'Weather_Condition' in df_dashboard.columns:
    df_dashboard['Weather_Condition'] = df_dashboard['Weather_Condition'].fillna('Không xác định')

print(" Dữ liệu Dashboard đã sạch sẽ!")
# Out:
#  Đang xử lý dữ liệu cho Dashboard...
#  Dữ liệu Dashboard đã sạch sẽ!

# %%
# 1 & 2. Traffic Signal và Junction: Bỏ qua không cần dịch
# Dữ liệu sẽ tự động giữ nguyên dạng True / False gốc của file

# 3. Sunrise_Sunset (Ngày/Đêm): Giữ nguyên Day/Night
if 'Sunrise_Sunset' in df_dashboard.columns:
    # Chỉ cần điền từ 'Day' vào những ô bị bỏ trống (fillna)
    df_dashboard['Sunrise_Sunset'] = df_dashboard['Sunrise_Sunset'].fillna('Day')

# Hiển thị kết quả để kiểm tra
display(df_dashboard[['City', 'Traffic_Signal', 'Sunrise_Sunset', 'Duration']].head())
# Out:
#            City  Traffic_Signal Sunrise_Sunset  Duration
# 0        Dayton           False          Night     314.0
# 1  Reynoldsburg           False          Night      30.0
# 2  Williamsburg            True          Night      30.0
# 3        Dayton           False          Night      30.0
# 4        Dayton            True            Day      30.0

# %%
import os

# --- LƯU TRỮ DỮ LIỆU ĐÃ LÀM SẠCH ---

# 1. Tạo thư mục 'output' (nếu chưa có)
# Bước này quan trọng vì trong ảnh cây thư mục của bạn chưa có folder output
if not os.path.exists('output'):
    os.makedirs('output')
    print(" Đã tạo thư mục 'output'")

# 2. Lưu file Dashboard (Quan trọng nhất để chạy App)
# Lưu ý: encoding='utf-8-sig' để giữ tiếng Việt không bị lỗi font khi mở bằng Excel
# index=False để bỏ cột số thứ tự (0, 1, 2...) thừa thãi
df_dashboard.to_csv('output/dashboard_data.csv', index=False, encoding='utf-8-sig')

print(" Đã lưu xong file tại: output/dashboard_data.csv")
# Out:
#  Đã lưu xong file tại: output/dashboard_data.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Cấu hình giao diện đẹp
sns.set_style("whitegrid") # Nền trắng có kẻ ô
plt.rcParams['figure.figsize'] = (12, 6) # Kích thước mặc định cho to
plt.rcParams['font.size'] = 12

# %%
plt.figure(figsize=(8, 5))
# Vẽ biểu đồ cột đếm số lượng
ax = sns.countplot(x='Severity', data=df_dashboard, palette='Reds')

plt.title('Distribution of Accident Severity', fontsize=15)
plt.xlabel('Severity Level (1: Minor -> 4: Severe)')
plt.ylabel('Number of Accidents')

# Hiện số trên đầu cột cho dễ nhìn
for p in ax.patches:
    ax.annotate(f'{int(p.get_height()):,}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23072\1062743225.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Severity', data=df_dashboard, palette='Reds')

# %%
plt.figure(figsize=(12, 6))

# Gom nhóm theo giờ và đếm
accidents_by_hour = df_dashboard.groupby('Hour').size()

# Vẽ biểu đồ đường
sns.lineplot(x=accidents_by_hour.index, y=accidents_by_hour.values, marker='o', color='darkred', linewidth=2.5)

plt.title('Number of Accidents by Hour of Day', fontsize=15)
plt.xlabel('Hour (0 - 23)')
plt.ylabel('Number of Accidents')
plt.xticks(range(0, 24)) # Show all 24 hours
plt.grid(True, linestyle='--')
plt.show()

# %%
plt.figure(figsize=(14, 7))

# 1. Tạo bảng Pivot (ngang là Giờ, dọc là Thứ)
heatmap_data = df_dashboard.pivot_table(index='Weekday', columns='Hour', values='Severity', aggfunc='count')

# Sắp xếp lại thứ tự từ Thứ 2 đến CN (thay vì 0-6)
days_order = [0, 1, 2, 3, 4, 5, 6] 
heatmap_data = heatmap_data.reindex(days_order)
yticklabels = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# 2. Vẽ Heatmap
sns.heatmap(heatmap_data, cmap='inferno', annot=False, fmt='d', yticklabels=yticklabels)

plt.title('Heatmap: Accident Frequency by Day of Week and Hour', fontsize=15)
plt.xlabel('Hour of Day')
plt.ylabel('Day of Week')
plt.show()

# %%
plt.figure(figsize=(12, 6))

# Lấy top 10 thành phố
top_cities = df_dashboard['City'].value_counts().head(10)

# Vẽ biểu đồ cột nằm ngang
sns.barplot(x=top_cities.values, y=top_cities.index, palette='viridis')

plt.title('Top 10 Cities with the Most Accidents', fontsize=15)
plt.xlabel('Number of Accidents')
plt.ylabel('City')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23072\3288697158.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_cities.values, y=top_cities.index, palette='viridis')

# %%
plt.figure(figsize=(15, 10))


sample_df = df_dashboard.sample(n=2000000, random_state=42)

# Vẽ Scatter plot (Kinh độ vs Vĩ độ)
sns.scatterplot(x='Start_Lng', y='Start_Lat', data=sample_df, 
                hue='Severity', palette='coolwarm', s=10, alpha=0.5)

plt.title('Map of Accident Distribution', fontsize=15)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Severity Level', loc='lower right')
plt.show()
